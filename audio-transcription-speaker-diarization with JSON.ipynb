# %%
#  Install PyTorch with GPU support
# !pip install torch torchaudio --quiet

#  Install PyAnnote for speaker diarization
# !pip install pyannote.audio --quiet

#  Install Whisper for speech-to-text
# !pip install openai-whisper --quiet

#  Install FFmpeg for audio processing
# !apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
from pyannote.audio import Pipeline
import torch
import whisper
import warnings

# Hugging Face Token
HUGGINGFACE_TOKEN = "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"
warnings.filterwarnings("ignore")

# %%
audio_file = "/kaggle/input/audio-test/input1.mp3"

# %%
#PyAnnote speaker diarization pipeline
pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token=HUGGINGFACE_TOKEN
)

#Move pipeline to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
pipeline.to(device)

#Load Whisper model for transcription
whisper_model = whisper.load_model("base")

# %%
import json

# !ffmpeg -i /kaggle/input/audio-test/input1.mp3 audio5.wav
audio_file = "audio5.wav"

# Run speaker diarization
print(" Processing audio for diarization...")
diarization = pipeline(audio_file)

# Run Whisper transcription
print(" Transcribing audio...")
transcription = whisper_model.transcribe(audio_file)

# Map PyAnnote speakers to friendly names
speaker_map = {}
speaker_count = 1

# Create a list to hold JSON entries
json_output = []

for segment in transcription['segments']:
    seg_start = segment['start']
    seg_end = segment['end']
    text = segment['text']

    # Find matching speaker
    speaker_overlap = {}
    for turn, _, speaker in diarization.itertracks(yield_label=True):
        overlap_start = max(seg_start, turn.start)
        overlap_end = min(seg_end, turn.end)
        overlap = max(0, overlap_end - overlap_start)

        if overlap > 0:
            if speaker not in speaker_overlap:
                speaker_overlap[speaker] = 0
            speaker_overlap[speaker] += overlap

    if speaker_overlap:
        matched_speaker = max(speaker_overlap, key=speaker_overlap.get)
        if matched_speaker not in speaker_map:
            speaker_map[matched_speaker] = f"Speaker {speaker_count}"
            speaker_count += 1
        speaker_name = speaker_map[matched_speaker]
    else:
        speaker_name = "Speaker ?"

    # Add entry to JSON output
    json_output.append({
        "speaker": speaker_name,
        "text": text.strip(),
        "start": round(seg_start, 1),
        "end": round(seg_end, 1)
    })

# Write JSON output to file
output_json_file = "transcript.json"
with open(output_json_file, "w") as json_file:
    json.dump(json_output, json_file, indent=4)

print(f"\n Transcript saved as: {output_json_file}")

#  Print JSON to console
print(json.dumps(json_output, indent=4))
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5b2c17ef4480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audio-test/input1.mp3':
#   Metadata:
#     encoder         : Lavf58.45.100
#   Duration: 00:10:28.01, start: 0.000000, bitrate: 128 kb/s
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio5.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=  117752kB time=00:10:27.98 bitrate=1536.1kbits/s speed= 598x
# video:0kB audio:117752kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000065%
#  Processing audio for diarization...
#  Transcribing audio...
#
#  Transcript saved as: transcript.json
# [
#     {
#         "speaker": "Speaker 1",
#         "text": "the Google Cloud platform as well as Stripe.",
#         "start": 0.0,
#         "end": 3.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yes, I've received both of these advice.",
#         "start": 3.6,
#         "end": 7.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Perfect.",
#         "start": 7.5,
#         "end": 9.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Let me know if you see any issues.",
#         "start": 9.7,
#         "end": 11.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "We've had some other developers have access issues,",
#         "start": 11.8,
#         "end": 14.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "even though they were given ownership permission.",
#         "start": 14.3,
#         "end": 16.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I don't know what that's about, but let me know",
#         "start": 16.6,
#         "end": 19.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "if you're ready into any problems.",
#         "start": 19.2,
#         "end": 20.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'm still waiting on the client to sign up",
#         "start": 20.8,
#         "end": 22.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "for the Nvidia Enterprise.",
#         "start": 22.4,
#         "end": 25.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I believe you need to be added to that as well.",
#         "start": 25.4,
#         "end": 27.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And also he needs to add you to Mailgun,",
#         "start": 27.0,
#         "end": 29.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "because I just don't have the permissions to do them myself.",
#         "start": 29.0,
#         "end": 32.1
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Right.",
#         "start": 32.1,
#         "end": 33.0
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Sure.",
#         "start": 33.0,
#         "end": 34.0
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I'll run a text from the team to see if they can access.",
#         "start": 34.0,
#         "end": 37.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "And they have the necessary access for the deployment of them.",
#         "start": 37.5,
#         "end": 42.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "OK.",
#         "start": 42.8,
#         "end": 43.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Cool.",
#         "start": 43.3,
#         "end": 45.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Go.",
#         "start": 45.3,
#         "end": 46.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Go.",
#         "start": 46.3,
#         "end": 46.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Go ahead.",
#         "start": 46.8,
#         "end": 47.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah.",
#         "start": 47.6,
#         "end": 48.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Yeah.",
#         "start": 48.6,
#         "end": 49.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Next on my agenda is I have a few questions",
#         "start": 49.6,
#         "end": 53.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "about the features that you mentioned in your email.",
#         "start": 53.1,
#         "end": 55.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So first is mouse scrolling.",
#         "start": 55.6,
#         "end": 57.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "You mentioned that would only take a couple of days.",
#         "start": 57.3,
#         "end": 59.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'd like to know if that's near completion.",
#         "start": 59.3,
#         "end": 62.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah.",
#         "start": 62.4,
#         "end": 63.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So it's going to take one or two days,",
#         "start": 63.4,
#         "end": 66.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "but it's expected to be completed within this week.",
#         "start": 66.7,
#         "end": 72.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So for the next, the other two features",
#         "start": 72.3,
#         "end": 75.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "that we discussed and created as a change request,",
#         "start": 75.6,
#         "end": 80.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "the screenshots separately for the negotiated parts",
#         "start": 80.8,
#         "end": 85.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and the other search bug thing.",
#         "start": 85.4,
#         "end": 90.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So for both of those, I provided you an estimated timeline.",
#         "start": 90.2,
#         "end": 93.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "And I guess Humza will reach out to you regarding the course.",
#         "start": 93.7,
#         "end": 100.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Yeah.",
#         "start": 100.8,
#         "end": 101.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "The client's interested in adding both of those.",
#         "start": 101.8,
#         "end": 103.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "He's cool with the timeline.",
#         "start": 103.2,
#         "end": 104.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "He just needs the price.",
#         "start": 104.6,
#         "end": 106.5
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I haven't heard from Humza yet.",
#         "start": 106.5,
#         "end": 108.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Would you be able to poke him for me?",
#         "start": 108.4,
#         "end": 109.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I do that.",
#         "start": 109.7,
#         "end": 110.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'd like to get the price over to the client today,",
#         "start": 110.2,
#         "end": 112.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "so he can decide if he wants to move forward with this ASAP.",
#         "start": 112.8,
#         "end": 117.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Sure.",
#         "start": 117.4,
#         "end": 118.1
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I think Humza, hopefully he will provide you with the cost.",
#         "start": 118.1,
#         "end": 125.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Like I think I'll still remind him and share your concern.",
#         "start": 125.8,
#         "end": 132.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "OK.",
#         "start": 132.3,
#         "end": 132.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Thanks.",
#         "start": 132.8,
#         "end": 134.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I have a few more questions, but I",
#         "start": 134.0,
#         "end": 135.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "want to allow you an opportunity to provide me",
#         "start": 135.8,
#         "end": 138.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "with any updates that you have.",
#         "start": 138.2,
#         "end": 139.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I've been talking this all time.",
#         "start": 139.8,
#         "end": 141.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "No.",
#         "start": 141.6,
#         "end": 142.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So basically, we have this goal for your feedback.",
#         "start": 142.4,
#         "end": 146.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "In the last email, you mentioned that we were just",
#         "start": 146.7,
#         "end": 149.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "in the platform itself and we provided the feedback.",
#         "start": 149.2,
#         "end": 153.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So this is entirely a feedback call.",
#         "start": 153.3,
#         "end": 155.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "And I hope to be hearing any feedback you have for me,",
#         "start": 155.5,
#         "end": 160.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "starting the platform and everything.",
#         "start": 160.3,
#         "end": 163.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Well, from a layman's perspective, the GUI looks great.",
#         "start": 163.4,
#         "end": 167.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I don't have any issues or concerns.",
#         "start": 167.6,
#         "end": 169.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'm still waiting for the client to give me",
#         "start": 169.7,
#         "end": 171.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "his final feedback, but I don't anticipate",
#         "start": 171.8,
#         "end": 173.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "there being anything that needs to be adjusted,",
#         "start": 173.8,
#         "end": 176.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "likely only cosmetic things.",
#         "start": 176.8,
#         "end": 178.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "But since I myself am not a developer,",
#         "start": 178.8,
#         "end": 181.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "some of these items are for me to test specifically the API.",
#         "start": 181.2,
#         "end": 185.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Also, we're going to want to use the API for immediately",
#         "start": 185.2,
#         "end": 188.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "is for peace of mind.",
#         "start": 188.6,
#         "end": 191.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And also we're interested in utilizing the API",
#         "start": 191.0,
#         "end": 195.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to use the matrix to annotate changes",
#         "start": 195.7,
#         "end": 200.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "within overhead imagery, specifically imagery",
#         "start": 200.4,
#         "end": 204.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "that's being analyzed in ArcGIS.",
#         "start": 204.8,
#         "end": 208.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So I'm curious if there's a way.",
#         "start": 208.6,
#         "end": 211.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Well, number one, I want you to confirm",
#         "start": 211.8,
#         "end": 213.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "that we can use Centurion with ArcGIS",
#         "start": 213.4,
#         "end": 217.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to conduct this change detection, utilizing the matrix.",
#         "start": 217.4,
#         "end": 222.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Is that something that Centurion can do?",
#         "start": 222.1,
#         "end": 225.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "ArcGIS.",
#         "start": 225.4,
#         "end": 228.1
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So I'm not a technical guy over here.",
#         "start": 228.1,
#         "end": 232.0
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I'll need to ask my viewer queries",
#         "start": 232.0,
#         "end": 236.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and ask them to the technical lead, the Dirt and D,",
#         "start": 236.7,
#         "end": 241.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and he can provide me a response to your queries.",
#         "start": 241.3,
#         "end": 246.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "OK.",
#         "start": 246.4,
#         "end": 247.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So if you want to have some other meeting",
#         "start": 247.9,
#         "end": 251.0
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "in which you can discuss, or if you can provide me these queries,",
#         "start": 251.0,
#         "end": 254.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "all of the queries are contents.",
#         "start": 254.7,
#         "end": 256.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So I can forward to him, or I can maybe have a false",
#         "start": 256.7,
#         "end": 260.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "picture, and then we can discuss it.",
#         "start": 260.4,
#         "end": 264.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Let's see if we can clear it up over email first.",
#         "start": 264.6,
#         "end": 267.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'll itemize my questions.",
#         "start": 267.6,
#         "end": 271.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And I'll also explain what ArcGIS is.",
#         "start": 271.6,
#         "end": 273.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "If he's not familiar, it's more of the on the GIS side",
#         "start": 273.7,
#         "end": 277.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "of image analysis, so he may not be aware.",
#         "start": 277.2,
#         "end": 280.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "But the goal is to be able to use Centurion",
#         "start": 280.9,
#         "end": 283.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "as a user's change detection feature",
#         "start": 283.6,
#         "end": 287.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to eat up the image analysis process.",
#         "start": 287.0,
#         "end": 291.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Typically, the software is used by the DOD",
#         "start": 291.2,
#         "end": 295.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to analyze changes in topography.",
#         "start": 295.7,
#         "end": 297.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Or if we're talking about drones,",
#         "start": 297.9,
#         "end": 300.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "they plug in drone or high altitude still imagery.",
#         "start": 300.3,
#         "end": 304.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And they'll make certain passes.",
#         "start": 304.0,
#         "end": 305.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "The military will use those drones",
#         "start": 305.3,
#         "end": 306.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to make certain passes over combat areas.",
#         "start": 306.9,
#         "end": 309.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So on day one, they can see a baseline of what the area is like.",
#         "start": 309.2,
#         "end": 313.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And then on subsequent passes, they",
#         "start": 313.6,
#         "end": 315.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "can take images of the exact same location, a geocordance,",
#         "start": 315.2,
#         "end": 319.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and then identify any changes.",
#         "start": 319.2,
#         "end": 321.7
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So this would be like sort of a first phase for connoisseurs.",
#         "start": 321.7,
#         "end": 325.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "And we would like Centurion to be able to replace the human",
#         "start": 325.0,
#         "end": 328.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "who's doing that, where we give the first image, the second image,",
#         "start": 328.6,
#         "end": 332.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and Centurion could identify any changes",
#         "start": 332.0,
#         "end": 334.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and point that out immediately.",
#         "start": 334.4,
#         "end": 336.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So I'd like to be able to see how the API can be plugged into that application",
#         "start": 336.4,
#         "end": 341.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and others like it to be able to perform this task.",
#         "start": 341.0,
#         "end": 347.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah.",
#         "start": 347.4,
#         "end": 347.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So APIs, I guess, on my perspective, I guess the APIs",
#         "start": 347.9,
#         "end": 353.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "are general for use of any kind of applications.",
#         "start": 353.3,
#         "end": 358.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "They are not just issues with some supporting",
#         "start": 358.8,
#         "end": 361.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "some specific applications such as, you know,",
#         "start": 361.2,
#         "end": 364.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "we are going to work with Stribe, and we are going to integrate Stribe.",
#         "start": 364.4,
#         "end": 367.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So Stribe, the API part is API keys are different,",
#         "start": 367.5,
#         "end": 372.0
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "but the API is the same with the URL and everything.",
#         "start": 372.0,
#         "end": 375.1
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So if I am using a finder to mobile application,",
#         "start": 375.1,
#         "end": 378.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "if I am well, you know, better application,",
#         "start": 378.8,
#         "end": 381.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and no matter what performance I do,",
#         "start": 381.4,
#         "end": 383.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "the application is to Stribe can be integrated",
#         "start": 383.3,
#         "end": 386.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "in any kind of PSP application.",
#         "start": 386.2,
#         "end": 388.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So I guess the Centurion is also based on that similar",
#         "start": 388.2,
#         "end": 392.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and developed on the similar thing,",
#         "start": 392.9,
#         "end": 394.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and on the industry standard that it can be used by any of the applications.",
#         "start": 394.8,
#         "end": 399.3
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "But sure, you can share your queries with me.",
#         "start": 399.3,
#         "end": 401.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "And I can forward those to the technical,",
#         "start": 401.7,
#         "end": 405.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "in-leaf, and then I can have a response from that.",
#         "start": 405.9,
#         "end": 410.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I'll respond from him, and you can have chat with that.",
#         "start": 410.9,
#         "end": 415.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "OK.",
#         "start": 415.4,
#         "end": 416.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "That sounds good.",
#         "start": 416.4,
#         "end": 417.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Cool.",
#         "start": 417.8,
#         "end": 420.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "That's it.",
#         "start": 420.1,
#         "end": 420.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Oh, I did mention, I believe, to either you,",
#         "start": 420.9,
#         "end": 425.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Homs are both, that we were interested in a hard copy version of Centurion,",
#         "start": 425.1,
#         "end": 430.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "a version that can be printed on disks.",
#         "start": 430.1,
#         "end": 433.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I talked to the customer last night, and that's actually,",
#         "start": 433.0,
#         "end": 436.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "he's changed his mind on that.",
#         "start": 436.2,
#         "end": 438.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "We're just have all of our clients,",
#         "start": 438.3,
#         "end": 440.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "our potential customers, rather, sign up for the program,",
#         "start": 440.6,
#         "end": 443.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and then they can have access to the features that way.",
#         "start": 443.8,
#         "end": 447.5
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So the way we intended.",
#         "start": 447.5,
#         "end": 449.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "In the future, we may still have a need for this,",
#         "start": 449.2,
#         "end": 451.3
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and if so, we'll reach out to you.",
#         "start": 451.3,
#         "end": 453.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "But right now, that need is kankzed.",
#         "start": 453.1,
#         "end": 455.5
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Oh, everything else is looks good to me.",
#         "start": 455.5,
#         "end": 458.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I'll test it one more time, and I'll also reach out to the client",
#         "start": 458.2,
#         "end": 461.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "to see if he's done with this testing.",
#         "start": 461.1,
#         "end": 462.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So we can provide you with a fine around a feedback,",
#         "start": 462.8,
#         "end": 464.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "and we can finally get this closed out.",
#         "start": 464.8,
#         "end": 466.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Great.",
#         "start": 466.9,
#         "end": 467.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah, sure.",
#         "start": 467.9,
#         "end": 468.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "You can provide it with a feedback and questions,",
#         "start": 468.4,
#         "end": 471.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and then we can build the dice to which production.",
#         "start": 471.2,
#         "end": 474.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "And more of what I've just checked with Homs,",
#         "start": 474.8,
#         "end": 477.4
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "and he will send you the proposal by even.",
#         "start": 477.4,
#         "end": 481.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So hopefully he will send it by end of the day.",
#         "start": 481.2,
#         "end": 484.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Right?",
#         "start": 484.8,
#         "end": 486.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "OK.",
#         "start": 486.9,
#         "end": 487.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "My evening.",
#         "start": 487.4,
#         "end": 489.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I don't know.",
#         "start": 489.5,
#         "end": 490.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "R is around my time is like 7pm right now over here.",
#         "start": 490.8,
#         "end": 495.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So I guess he'll share the email before our day.",
#         "start": 495.8,
#         "end": 501.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "I mean, he'll be pretty late over there now, right?",
#         "start": 501.2,
#         "end": 504.7
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah, yes.",
#         "start": 504.7,
#         "end": 506.4
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "OK.",
#         "start": 506.4,
#         "end": 507.2
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "So within the next few hours, I imagine.",
#         "start": 507.2,
#         "end": 508.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "That's good.",
#         "start": 508.8,
#         "end": 509.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Yeah, I hope it is because I just asked him to do that.",
#         "start": 509.8,
#         "end": 513.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "He's sending it by even.",
#         "start": 513.6,
#         "end": 516.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "OK, that works for me.",
#         "start": 516.9,
#         "end": 518.8
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "OK.",
#         "start": 518.8,
#         "end": 519.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "So anything else did it?",
#         "start": 519.6,
#         "end": 522.6
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "No, man.",
#         "start": 522.6,
#         "end": 523.2
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Oh, I got.",
#         "start": 523.2,
#         "end": 524.9
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Thank you, and we're taking this forward.",
#         "start": 524.9,
#         "end": 528.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "I'm looking forward to the feedback and the questions.",
#         "start": 528.5,
#         "end": 532.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "All right.",
#         "start": 532.6,
#         "end": 532.9
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "We'll send that over today.",
#         "start": 532.9,
#         "end": 533.8
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Thank you for your time.",
#         "start": 533.8,
#         "end": 534.6
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Take care.",
#         "start": 534.6,
#         "end": 535.5
#     },
#     {
#         "speaker": "Speaker 1",
#         "text": "Thank you.",
#         "start": 535.5,
#         "end": 536.1
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Goodbye.",
#         "start": 536.1,
#         "end": 537.0
#     },
#     {
#         "speaker": "Speaker 2",
#         "text": "Bye-bye.",
#         "start": 537.0,
#         "end": 538.4
#     }
# ]
